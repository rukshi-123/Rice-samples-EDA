# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("students.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.describe().T
# Out:
#                                     count     mean        std   min   25%  \
# Hours Studied                     10000.0   4.9929   2.589309   1.0   3.0
# Previous Scores                   10000.0  69.4457  17.343152  40.0  54.0
# Sleep Hours                       10000.0   6.5306   1.695863   4.0   5.0
# Sample Question Papers Practiced  10000.0   4.5833   2.867348   0.0   2.0
# Performance Index                 10000.0  55.2248  19.212558  10.0  40.0
#
#                                    50%   75%    max
# Hours Studied                      5.0   7.0    9.0
# Previous Scores                   69.0  85.0   99.0
# Sleep Hours                        7.0   8.0    9.0
# Sample Question Papers Practiced   5.0   7.0    9.0
# Performance Index                 55.0  71.0  100.0

# %%
df["Hours Studied"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       7
# 1       4
# 2       8
# 3       5
# 4       7
#        ..
# 9995    1
# 9996    7
# 9997    6
# 9998    9
# 9999    7
# Name: Hours Studied, Length: 10000, dtype: int64>

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
# using matplot
barch = df['Hours Studied'].value_counts
figsize = (6,4)
plt.bar(df['Hours Studied'],df['Previous Scores'])
plt.xlabel('Hours Studied')
plt.ylabel('Previous Score')
plt.title('bar chart example')
plt.show()

# %%
# visuvalization
plt.Figure(figsize=(5,3))
sns.histplot(df['Performance Index'])
plt.show()

# %%
df['Extracurricular Activities'].value_counts()
# Out:
# Extracurricular Activities
# No     5052
# Yes    4948
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
# histogarn using seaborn
sns.histplot(df,x='Performance Index',
             hue='Extracurricular Activities',
            stat='percent')
plt.title("histogram graph")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(df,x= 'Extracurricular Activities',hue='Extracurricular Activities')
plt.show()

# %%
corr = df.select_dtypes(include='number')
sns.heatmap(corr.corr(),annot=True,cmap='Accent',lw = 0.3)
plt.xticks(rotation= 45)
plt.yticks(rotation= 45)
plt.show()

# %% [markdown]
# feature extraction

# %% [markdown]
# feature encoding

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
df['Extracurricular Activities']= lab_enc.fit_transform(df['Extracurricular Activities'])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
#another method
#x= df.drop('Performance Index',axis=1)
#y = df['Performance Index']

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
x
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# split into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train ,y_test = train_test_split(x,y,test_size= 0.3)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x_test.shape,x_train.shape
# Out:
# ((3000, 5), (7000, 5))

# %%
y_test.shape,y_train.shape
# Out:
# ((3000,), (7000,))

# %% [markdown]
# data normalisation

# %%
from sklearn.preprocessing import StandardScaler
s_scale =StandardScaler()
x_train_scaled = s_scale.fit(x_train)

x_test_scaled = s_scale.fit_transform(x_test)

# %% [markdown]
# model building

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()
lin_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred  = lin_model.predict(x_test)
y_pred
# Out:
# array([47.75634073, 73.84285042, 91.11158543, ..., 63.33410074,
#        48.20484252, 54.55747156], shape=(3000,))

# %%
y_test
# Out:
# 2542    50.0
# 988     78.0
# 9281    89.0
# 6306    31.0
# 3590    73.0
#         ...
# 7679    33.0
# 2784    48.0
# 5043    63.0
# 9397    47.0
# 2761    55.0
# Name: Performance Index, Length: 3000, dtype: float64

# %%
# check the model accuracy 
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 98.91935519024109

# %%
# training accuracy
lin_model.score(x_train,y_train)*100
# Out:
# 98.8552878934849

# %%
# testing accuracy
lin_model.score(x_test,y_test)*100
# Out:
# 98.91935519024109
